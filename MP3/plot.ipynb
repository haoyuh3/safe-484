# %%
import numpy as np
import matplotlib.pyplot as plt
# bobx = np.load("bob_x.npy")
# boby = np.load("bob_y")
error = np.load("error_dist.npy")
plt.plot(error)
plt.xlabel("batch number")
plt.ylabel("Error_distance")
plt.title("Error_distance when Direction:4, Number of particls: 500, Rate: 10hz, Sensor Limit: 15, top-right quadrant")
# Out:
# Text(0.5, 1.0, 'Error_distance when Direction:4, Number of particls: 500, Rate: 10hz, Sensor Limit: 15, top-right quadrant')

# %%
error1 = np.load("error_orientation.npy")
plt.plot(error1)
plt.xlabel("batch_number")
plt.ylabel("Error_Orientation [degree]")
plt.title("Error_Orientation when Direction:4, Number of particls: 500, Rate: 10hz, Sensor Limit: 15, top-right quadrant")
# Out:
# Text(0.5, 1.0, 'Error_Orientation when Direction:4, Number of particls: 500, Rate: 10hz, Sensor Limit: 15, top-right quadrant')
